# %%
# autograd
import torch

# %%
x = torch.tensor(3.0, requires_grad = True)

# %%
y = x**2
# forward prop

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# it makes a computational graph between relation of x and y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()
# like backprop

# %%
x.grad
# Out:
# tensor(6.)

# %%
# example 2 y = x sqr2 and z = sin(y)
x = torch.tensor(3.0, requires_grad= True)

# %%
y = x ** 2

# %%
z = torch.sin(y)

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
z
# Out:
# tensor(0.4121, grad_fn=<SinBackward0>)

# %%
z.backward()

# %%
x.grad
# gradient
# Out:
# tensor(-5.4668)

# %%
# we cant do y.grad as gradients are done for leaf nodes only, not the intermediate nodes.

# %%
# neural network workflow
# Inputs
x = torch.tensor(6.7)
# input feature
y = torch.tensor(0.0)
# true label whihc is binary

w = torch.tensor(1.0, requires_grad= True)
b = torch.tensor(0.0, requires_grad= True)

# %%
# binary cross entropy loss for scalar
def binary_cross_entropy(prediction, target):
    epsilon = 1e-8
    prediction = torch.clamp(prediction, epsilon, 1-epsilon)
    return -(target * torch.log(prediction) + (1 - target) * torch.log(1 - prediction))

# %%
# forward pass
z = w * x + b
y_pred = torch.sigmoid(z)

# %%
# compute binary cross entropy loss
loss = binary_cross_entropy(y_pred, y)

# %%
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)
# Out:
# tensor(6.6918)
# tensor(0.9988)

# %%
# example 3
x = torch.tensor([1.0, 2.0, 3.0], requires_grad=True)

# %%
y = (x**2).mean()

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %%
x = torch.tensor(2., requires_grad=True)

# %%
y = x ** 2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(8.)

# %%
# if you run forward pass and then backward again, the gradients will accumulate, 4, 8, 12, 16 and so on...so we use clearing grad..
x.grad.zero_()
# Out:
# tensor(0.)

# %%
# stopping grad tracking
# option 1 : requires_grad_(False)
# option 2: detach()
#  option 3 : torch.no_grad()
